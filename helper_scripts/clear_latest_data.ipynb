# %%
import os
import pandas as pd

# %%
home_dir = "/bask/projects/v/vjgo8416-amber/projects/gbif-species-trainer-AMI-fork/"
data_dir = "/bask/projects/v/vjgo8416-amber/data/gbif-species-trainer-AMI-fork/"

# %%
slr = pd.read_csv(os.path.join(home_dir,"data_download","slr.csv"))

# %%
slr.shape
# Out:
# (194, 11)

# %%
slr.head(10)
# Out:
#    accepted_taxon_key   order_name family_name   genus_name  \
# 0                  -1  Lepidoptera   Noctuidae      Agrotis
# 1             1770880  Lepidoptera   Noctuidae      Agrotis
# 2             1787610  Lepidoptera   Noctuidae       Hadena
# 3             1789086  Lepidoptera   Noctuidae     Hecatera
# 4             1789076  Lepidoptera   Noctuidae     Hecatera
# 5             8108800  Lepidoptera   Noctuidae  Helicoverpa
# 6             4534676  Lepidoptera   Noctuidae    Heliothis
# 7             4534675  Lepidoptera   Noctuidae    Heliothis
# 8             4534681  Lepidoptera   Noctuidae    Heliothis
# 9             4534686  Lepidoptera   Noctuidae    Heliothis
#
#     search_species_name     gbif_species_name  confidence    status  \
# 0     Agrotis spinifera              NotAvail          98  ACCEPTED
# 1   Agrotis vestigialis   Agrotis vestigialis          99  ACCEPTED
# 2       Hadena perplexa       Hadena perplexa          99  ACCEPTED
# ...

# %%
for idx, iRow in slr.iterrows():
        
    if iRow["gbif_species_name"] != "NotAvail":
        
        # Get the folder name
        dirname = os.path.join(data_dir,"gbif_images","try_wrapper",iRow["family_name"],iRow["genus_name"],iRow["gbif_species_name"])
        
        if os.path.isdir(dirname):
            print('Deleting...')
            shutil.rmtree(dirname)
            print('Deleted!')
        else:
            print('Not a dir')
# Out:
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# Not a dir
# ...
