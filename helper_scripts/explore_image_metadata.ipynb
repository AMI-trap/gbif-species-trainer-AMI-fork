# %%
import json

# %%
f = open("/Users/lbokeria/Documents/projects/gbif-species-trainer-data/gbif_images/try_wrapper/Sesiidae/Bembecia/Bembecia ichneumoniformis/meta_data.json")

data = json.loads(f.read())

# %%
data
# Out:
# {'3880383834.jpg': {'decimalLatitude': 57.67546,
#   'decimalLongitude': 15.00141,
#   'order': 'Lepidoptera',
#   'family': 'Sesiidae',
#   'genus': 'Bembecia',
#   'species': 'Bembecia ichneumoniformis',
#   'acceptedScientificName': 'Bembecia ichneumoniformis (Denis & Schiffermüller), 1775',
#   'year': 2022.0,
#   'month': 7.0,
#   'day': 22.0,
#   'datasetName': 'Artportalen',
#   'taxonID': 'urn:lsid:dyntaxa.se:Taxon:100464',
#   'acceptedTaxonKey': 1940838,
#   'lifeStage': 'Imago',
#   'basisOfRecord': 'HUMAN_OBSERVATION'},
#  '3434031441.jpg': {'decimalLatitude': 56.75915,
#   'decimalLongitude': 16.64783,
#   'order': 'Lepidoptera',
#   'family': 'Sesiidae',
#   'genus': 'Bembecia',
#   'species': 'Bembecia ichneumoniformis',
#   'acceptedScientificName': 'Bembecia ichneumoniformis (Denis & Schiffermüller), 1775',
#   'year': 2021.0,
#   'month': 6.0,
#   'day': 22.0,
#   'datasetName': 'Artportalen',
#   'taxonID': 'urn:lsid:dyntaxa.se:Taxon:100464',
# ...
