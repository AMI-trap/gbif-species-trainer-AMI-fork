# %%
import pandas as pd

# %%
pd.read_csv("./data_download/slr.csv")
# Out:
#      accepted_taxon_key   order_name family_name genus_name  \
# 0                    -1  Lepidoptera   Noctuidae    Agrotis
# 1               1770880  Lepidoptera   Noctuidae    Agrotis
# 2               1787610  Lepidoptera   Noctuidae     Hadena
# 3               1789086  Lepidoptera   Noctuidae   Hecatera
# 4               1789076  Lepidoptera   Noctuidae   Hecatera
# ..                  ...          ...         ...        ...
# 189             5112283  Lepidoptera   Noctuidae     Xestia
# 190             1790364  Lepidoptera   Noctuidae     Xylena
# 191             9174377  Lepidoptera   Noctuidae     Xylena
# 192             1790361  Lepidoptera   Noctuidae     Xylena
# 193             1768150  Lepidoptera   Noctuidae  Xylocampa
#
#      search_species_name    gbif_species_name  confidence    status  \
# 0      Agrotis spinifera             NotAvail          98  ACCEPTED
# 1    Agrotis vestigialis  Agrotis vestigialis          99  ACCEPTED
# ...
